# %%
import pandas as pd
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stop = list(stopwords.words('english'))
new_stop=['(',',','.','..','"',')','>','’','<','“','/','?']
stop.extend(new_stop)

porter = PorterStemmer()

URL_DATA = 'Dataset.xlsx'


def remove_punctuation(description):
    """Function to remove punctuation"""
    table = str.maketrans('', '', string.punctuation)
    return description.translate(table)


def remove_stopwords(text):
    """Function to removing stopwords"""
    text = [word.lower() for word in text.split() if word.lower() not in stop]
    return " ".join(text)


def stemmer(stem_text):
    """Function to apply stemming"""
    stem_text = [porter.stem(word) for word in stem_text.split()]
    return " ".join(stem_text)


def read_data(path):
    """Function to read and clean text data"""
    data = pd.read_excel(path, header=0, index_col=0)
    data = data[['Judgment','Judgment Status']].copy()
    data['Judgment'] = data['Judgment'].astype(str)
    data['Judgment'] = data['Judgment'].apply(remove_punctuation)
    data['Judgment'] = data['Judgment'].apply(remove_stopwords)
    data['Judgment'] = data['Judgment'].apply(stemmer)
    return data


if __name__ == '__main__':
    dataset = read_data(URL_DATA)
    print(dataset.shape)
    print(dataset)
    dataset.to_csv('New Data.csv',encoding='utf-8')
# Out:
# C:\Users\Surisetty\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (320, 2)
#                                               Judgment  Judgment Status
# Id
# 1    appeal judgment decre bombay high court stone ...                1
# 2    applic articl 32 1 constitut enforc applic fun...                2
# 3    appeal judgment high court hyderabad articl 37...                0
# 4    appeal articl 3744 constitut judgment decre hi...                0
# 5    petit art 136 constitut pray special leav appe...                3
# ..                                                 ...              ...
# 316  1 revision applic instanc defend state orissa ...                1
# 317  1 writ petit taken question valid decis nagaon...                3
# 318  saptangshu basu senior advoc mr partha basu mr...                3
# 319  mr arunava ghosh mr supriya ranjan saha advoc ...                3
# 320  introduct whether seat parliament legislatur s...                1
#
# [320 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Activation, Dropout, GlobalMaxPool1D, Conv1D
from tensorflow.keras.layers import Embedding
from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.layers.convolutional import MaxPooling1D
from keras import utils

# %%
df = pd.read_csv('New Data.csv', header=0,index_col=0)
df.head()
# Out:
#                                              Judgment  Judgment Status
# Id
# 1   appeal judgment decre bombay high court stone ...                1
# 2   applic articl 32 1 constitut enforc applic fun...                2
# 3   appeal judgment high court hyderabad articl 37...                0
# 4   appeal articl 3744 constitut judgment decre hi...                0
# 5   petit art 136 constitut pray special leav appe...                3

# %%
sentences = df['Judgment']
y = df['Judgment Status']

from sklearn.model_selection import train_test_split

sentences_train, sentences_test, train_y, test_y = train_test_split(sentences, y, test_size=0.25, random_state=42)

# %%
tokenize = Tokenizer(num_words=10000)
tokenize.fit_on_texts(sentences_train)

train_X = tokenize.texts_to_sequences(sentences_train)
test_X = tokenize.texts_to_sequences(sentences_test)

vocab_size = len(tokenize.word_index) + 1  

print(sentences_train[2])
print(train_X[0])
# Out:
95, 500, 1494, 130, 703, 532, 130, 6, 8, 1826, 962, 195, 95, 551, 130, 249, 8, 3908, 2756, 2561, 310, 519, 5187, 771, 1569, 472, 295, 88, 414, 242, 138, 84, 415, 447, 7197, 24, 97, 6, 551, 88, 234, 1569, 414, 9600, 9601, 9602, 437, 3, 346, 414, 415, 84, 362, 89, 267, 121, 84, 2974, 1569, 205, 57, 67, 249, 62, 128, 330, 9, 1, 376, 135, 81, 71, 88, 414, 57, 1750, 88, 1149, 310, 414, 57, 415, 84, 3909, 121, 84, 1149, 310, 59, 415, 511, 71, 1824, 560, 414, 415, 84, 492, 174, 114, 3, 643, 771, 1359, 60, 414, 170, 2973, 2757, 2231, 3, 84, 34, 674, 414, 2170, 114, 114, 104, 371, 414, 674, 84, 186, 2171, 492, 174, 1307, 64, 16, 1710, 52, 1236, 2168, 162, 414, 81, 162, 174, 2, 414, 77, 28, 660, 69, 1997, 3269, 156, 415, 5991, 84, 1214, 970, 2172, 3908, 123, 238, 1905, 162, 414, 1418, 566, 5188, 1868, 16, 2116, 78, 1868, 447, 970, 2173, 3908, 2174, 580, 414, 16, 415, 84, 1101, 372, 590, 162, 1359, 60, 267, 84, 415, 74, 73, 137, 162, 1359, 3, 601, 71, 591, 45, 292, 448, 224, 3637, 3638, 57, 1040, 4, 970, 1125, 1711, 1360, 772, 5189, 332, 438, 752, 138, 84, 414, 560, 415, 318, 1149, 310, 1162, 5187, 283, 414, 84, 88, 414, 1024, 525, 11, 199, 747, 9603, 142, 241, 3, 5992, 748, 681, 9604, 148, 3270, 826, 9605, 462, 100, 826, 46, 241, 826, 295, 241, 52, 9606, 826, 295, 241, 1946, 1569, 199, 295, 573, 826, 295, 241, 826, 295, 241, 5190, 187, 826, 46, 241, 1676, 23, 34, 52, 826, 46, 241, 89, 526, 95, 39, 1088, 573, 520, 826, 295, 241, 500, 303, 95, 81, 214, 80, 1569, 295, 67, 998, 77, 172, 2561, 110, 337, 2, 987, 224, 592, 1636, 3639, 414, 55, 415, 84, 310, 57, 111, 26, 5187, 34, 1569, 88, 415, 84, 57, 3271, 998, 788, 1 ...

# %%
X_train = pad_sequences(train_X, padding='post', maxlen=1000)  
X_test = pad_sequences(test_X, padding='post', maxlen=1000)

# %%
embedding_dim = 8
maxlen=1000`
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=maxlen))
model.add(Conv1D(64, 3, activation='relu'))
model.add(Conv1D(64, 3, activation='relu'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(27, activation='softmax'))
model.add(Dense(4, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1000, 8)           137776
#
#  conv1d (Conv1D)             (None, 998, 64)           1600
#
#  conv1d_1 (Conv1D)           (None, 996, 64)           12352
#
#  max_pooling1d (MaxPooling1D  (None, 498, 64)          0
#  )
#
#  flatten (Flatten)           (None, 31872)             0
#
#  dense (Dense)               (None, 100)               3187300
#
#  dense_1 (Dense)             (None, 27)                2727
#
#  dense_2 (Dense)             (None, 4)                 112
#
# =================================================================
# Total params: 3,341,867
# Trainable params: 3,341,867
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
StartTime = time.time()
history = model.fit(X_train, train_y,
                    batch_size=32,
                    epochs=100,
                    validation_data=(X_test, test_y))
EndTime = time.time()
print(f"Time taken for Training and Classification: {EndTime - StartTime}s")
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 160ms/step - loss: 1.3705 - accuracy: 0.2917 - val_loss: 1.3526 - val_accuracy: 0.3625
# Epoch 2/100
# 8/8 [==============================] - 1s 102ms/step - loss: 1.3385 - accuracy: 0.4000 - val_loss: 1.3419 - val_accuracy: 0.3625
# Epoch 3/100
# 8/8 [==============================] - 1s 107ms/step - loss: 1.3249 - accuracy: 0.4000 - val_loss: 1.3500 - val_accuracy: 0.3625
# Epoch 4/100
# 8/8 [==============================] - 1s 106ms/step - loss: 1.3084 - accuracy: 0.4000 - val_loss: 1.3370 - val_accuracy: 0.3625
# Epoch 5/100
# 8/8 [==============================] - 1s 101ms/step - loss: 1.2969 - accuracy: 0.4000 - val_loss: 1.3310 - val_accuracy: 0.3625
# Epoch 6/100
# 8/8 [==============================] - 1s 108ms/step - loss: 1.2564 - accuracy: 0.5208 - val_loss: 1.3193 - val_accuracy: 0.3750
# Epoch 7/100
# 8/8 [==============================] - 1s 107ms/step - loss: 1.1901 - accuracy: 0.6542 - val_loss: 1.3041 - val_accuracy: 0.3750
# Epoch 8/100
# 8/8 [==============================] - 1s 103ms/step - loss: 1.1463 - accuracy: 0.6875 - val_loss: 1.2972 - val_accuracy: 0.3875
# Epoch 9/100
# 8/8 [==============================] - 1s 101ms/step - loss: 1.1287 - accuracy: 0.6792 - val_loss: 1.2858 - val_accuracy: 0.4500
# Epoch 10/100
# 8/8 [==============================] - 1s 108ms/step - loss: 1.1021 - accuracy: 0.7208 - val_loss: 1.2861 - val_accuracy: 0.4125
# Epoch 11/100
# 8/8 [==============================] - 1s 104ms/step - loss: 1.0855 - accuracy: 0.7375 - val_loss: 1.2740 - val_accuracy: 0.4375
# Epoch 12/100
# 8/8 [==============================] - 1s 106ms/step - loss: 1.0672 - accuracy: 0.7542 - val_loss: 1.2857 - val_accuracy: 0.3625
# Epoch 13/100
# 8/8 [==============================] - 1s 99ms/step - loss: 1.0554 - accuracy: 0.7625 - val_loss: 1.2703 - val_accuracy: 0.3875
# Epoch 14/100
# 8/8 [==============================] - 1s 101ms/step - loss: 1.0356 - accuracy: 0.7958 - val_loss: 1.2482 - val_accuracy: 0.5000
# Epoch 15/100
# 8/8 [==============================] - 1s 100ms/step - loss: 1.0235 - accuracy: 0.8042 - val_loss: 1.2599 - val_accuracy: 0.4250
# Epoch 16/100
# 8/8 [==============================] - 1s 101ms/step - loss: 0.9970 - accuracy: 0.8542 - val_loss: 1.2694 - val_accuracy: 0.4000
# Epoch 17/100
# 8/8 [==============================] - 1s 102ms/step - loss: 0.9805 - accuracy: 0.8792 - val_loss: 1.2430 - val_accuracy: 0.4375
# Epoch 18/100
# 8/8 [==============================] - 1s 105ms/step - loss: 0.9681 - accuracy: 0.8750 - val_loss: 1.2342 - val_accuracy: 0.4375
# Epoch 19/100
# 8/8 [==============================] - 1s 104ms/step - loss: 0.9557 - accuracy: 0.8792 - val_loss: 1.2330 - val_accuracy: 0.4125
# Epoch 20/100
# 8/8 [==============================] - 1s 102ms/step - loss: 0.9427 - accuracy: 0.8917 - val_loss: 1.2447 - val_accuracy: 0.4625
# Epoch 21/100
# 8/8 [==============================] - 1s 102ms/step - loss: 0.9300 - accuracy: 0.8958 - val_loss: 1.3046 - val_accuracy: 0.3500
# Epoch 22/100
# 8/8 [==============================] - 1s 102ms/step - loss: 0.9158 - accuracy: 0.9083 - val_loss: 1.3287 - val_accuracy: 0.3875
# Epoch 23/100
# 8/8 [==============================] - 1s 102ms/step - loss: 0.8902 - accuracy: 0.9292 - val_loss: 1.3210 - val_accuracy: 0.3750
# Epoch 24/100
# 8/8 [==============================] - 1s 103ms/step - loss: 0.8915 - accuracy: 0.9167 - val_loss: 1.2558 - val_accuracy: 0.4500
# Epoch 25/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.9032 - accuracy: 0.8625 - val_loss: 1.3271 - val_accuracy: 0.4000
# Epoch 26/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.8756 - accuracy: 0.9042 - val_loss: 1.2900 - val_accuracy: 0.4375
# Epoch 27/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.8379 - accuracy: 0.9667 - val_loss: 1.3062 - val_accuracy: 0.4375
# Epoch 28/100
# 8/8 [==============================] - 1s 105ms/step - loss: 0.8205 - accuracy: 0.9750 - val_loss: 1.2955 - val_accuracy: 0.4250
# Epoch 29/100
# 8/8 [==============================] - 1s 102ms/step - loss: 0.8073 - accuracy: 0.9750 - val_loss: 1.2471 - val_accuracy: 0.4500
# Epoch 30/100
# 8/8 [==============================] - 1s 100ms/step - loss: 0.7970 - accuracy: 0.9750 - val_loss: 1.2321 - val_accuracy: 0.4500
# Epoch 31/100
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7841 - accuracy: 0.9792 - val_loss: 1.2432 - val_accuracy: 0.4375
# Epoch 32/100
# 8/8 [==============================] - 1s 107ms/step - loss: 0.7744 - accuracy: 0.9792 - val_loss: 1.2534 - val_accuracy: 0.4500
# Epoch 33/100
# 8/8 [==============================] - 1s 104ms/step - loss: 0.7649 - accuracy: 0.9792 - val_loss: 1.2586 - val_accuracy: 0.4375
# Epoch 34/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.7558 - accuracy: 0.9792 - val_loss: 1.2609 - val_accuracy: 0.4375
# Epoch 35/100
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7468 - accuracy: 0.9792 - val_loss: 1.2616 - val_accuracy: 0.4375
# Epoch 36/100
# 8/8 [==============================] - 1s 99ms/step - loss: 0.7380 - accuracy: 0.9792 - val_loss: 1.2617 - val_accuracy: 0.4375
# Epoch 37/100
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7295 - accuracy: 0.9792 - val_loss: 1.2613 - val_accuracy: 0.4500
# Epoch 38/100
# 8/8 [==============================] - 1s 120ms/step - loss: 0.7212 - accuracy: 0.9792 - val_loss: 1.2610 - val_accuracy: 0.4500
# Epoch 39/100
# 8/8 [==============================] - 1s 117ms/step - loss: 0.7131 - accuracy: 0.9792 - val_loss: 1.2608 - val_accuracy: 0.4500
# Epoch 40/100
# 8/8 [==============================] - 1s 115ms/step - loss: 0.7053 - accuracy: 0.9792 - val_loss: 1.2606 - val_accuracy: 0.4500
# Epoch 41/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.6974 - accuracy: 0.9792 - val_loss: 1.2607 - val_accuracy: 0.4375
# Epoch 42/100
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6899 - accuracy: 0.9792 - val_loss: 1.2610 - val_accuracy: 0.4375
# Epoch 43/100
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6825 - accuracy: 0.9792 - val_loss: 1.2615 - val_accuracy: 0.4375
# Epoch 44/100
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6751 - accuracy: 0.9792 - val_loss: 1.2621 - val_accuracy: 0.4375
# Epoch 45/100
# 8/8 [==============================] - 1s 113ms/step - loss: 0.6680 - accuracy: 0.9792 - val_loss: 1.2626 - val_accuracy: 0.4375
# Epoch 46/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6610 - accuracy: 0.9792 - val_loss: 1.2633 - val_accuracy: 0.4375
# Epoch 47/100
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6542 - accuracy: 0.9792 - val_loss: 1.2639 - val_accuracy: 0.4375
# Epoch 48/100
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6474 - accuracy: 0.9792 - val_loss: 1.2649 - val_accuracy: 0.4375
# Epoch 49/100
# 8/8 [==============================] - 1s 108ms/step - loss: 0.6407 - accuracy: 0.9792 - val_loss: 1.2656 - val_accuracy: 0.4500
# Epoch 50/100
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6342 - accuracy: 0.9792 - val_loss: 1.2664 - val_accuracy: 0.4500
# Epoch 51/100
# 8/8 [==============================] - 1s 113ms/step - loss: 0.6278 - accuracy: 0.9792 - val_loss: 1.2673 - val_accuracy: 0.4500
# Epoch 52/100
# 8/8 [==============================] - 1s 107ms/step - loss: 0.6216 - accuracy: 0.9792 - val_loss: 1.2681 - val_accuracy: 0.4500
# Epoch 53/100
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6153 - accuracy: 0.9792 - val_loss: 1.2691 - val_accuracy: 0.4500
# Epoch 54/100
# 8/8 [==============================] - 1s 114ms/step - loss: 0.6092 - accuracy: 0.9792 - val_loss: 1.2703 - val_accuracy: 0.4500
# Epoch 55/100
# 8/8 [==============================] - 1s 103ms/step - loss: 0.6032 - accuracy: 0.9792 - val_loss: 1.2715 - val_accuracy: 0.4500
# Epoch 56/100
# 8/8 [==============================] - 1s 100ms/step - loss: 0.5973 - accuracy: 0.9792 - val_loss: 1.2728 - val_accuracy: 0.4500
# Epoch 57/100
# 8/8 [==============================] - 1s 105ms/step - loss: 0.5915 - accuracy: 0.9792 - val_loss: 1.2740 - val_accuracy: 0.4500
# Epoch 58/100
# 8/8 [==============================] - 1s 121ms/step - loss: 0.5857 - accuracy: 0.9792 - val_loss: 1.2751 - val_accuracy: 0.4500
# Epoch 59/100
# 8/8 [==============================] - 1s 118ms/step - loss: 0.5801 - accuracy: 0.9792 - val_loss: 1.2765 - val_accuracy: 0.4500
# Epoch 60/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.5747 - accuracy: 0.9792 - val_loss: 1.2776 - val_accuracy: 0.4500
# Epoch 61/100
# 8/8 [==============================] - 1s 125ms/step - loss: 0.5691 - accuracy: 0.9792 - val_loss: 1.2791 - val_accuracy: 0.4500
# Epoch 62/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.5638 - accuracy: 0.9792 - val_loss: 1.2806 - val_accuracy: 0.4500
# Epoch 63/100
# 8/8 [==============================] - 1s 108ms/step - loss: 0.5586 - accuracy: 0.9792 - val_loss: 1.2819 - val_accuracy: 0.4500
# Epoch 64/100
# 8/8 [==============================] - 1s 107ms/step - loss: 0.5534 - accuracy: 0.9792 - val_loss: 1.2833 - val_accuracy: 0.4500
# Epoch 65/100
# 8/8 [==============================] - 1s 105ms/step - loss: 0.5483 - accuracy: 0.9792 - val_loss: 1.2849 - val_accuracy: 0.4500
# Epoch 66/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.5433 - accuracy: 0.9792 - val_loss: 1.2866 - val_accuracy: 0.4500
# Epoch 67/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.5383 - accuracy: 0.9792 - val_loss: 1.2883 - val_accuracy: 0.4500
# Epoch 68/100
# 8/8 [==============================] - 1s 117ms/step - loss: 0.5335 - accuracy: 0.9792 - val_loss: 1.2900 - val_accuracy: 0.4500
# Epoch 69/100
# 8/8 [==============================] - 1s 108ms/step - loss: 0.5287 - accuracy: 0.9792 - val_loss: 1.2917 - val_accuracy: 0.4500
# Epoch 70/100
# 8/8 [==============================] - 1s 123ms/step - loss: 0.5240 - accuracy: 0.9792 - val_loss: 1.2935 - val_accuracy: 0.4500
# Epoch 71/100
# 8/8 [==============================] - 1s 107ms/step - loss: 0.5193 - accuracy: 0.9792 - val_loss: 1.2953 - val_accuracy: 0.4500
# Epoch 72/100
# 8/8 [==============================] - 1s 106ms/step - loss: 0.5148 - accuracy: 0.9792 - val_loss: 1.2973 - val_accuracy: 0.4375
# Epoch 73/100
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5102 - accuracy: 0.9792 - val_loss: 1.2992 - val_accuracy: 0.4375
# Epoch 74/100
# 8/8 [==============================] - 1s 102ms/step - loss: 0.5057 - accuracy: 0.9792 - val_loss: 1.3012 - val_accuracy: 0.4375
# Epoch 75/100
# 8/8 [==============================] - 1s 106ms/step - loss: 0.5013 - accuracy: 0.9792 - val_loss: 1.3033 - val_accuracy: 0.4375
# Epoch 76/100
# 8/8 [==============================] - 1s 116ms/step - loss: 0.4969 - accuracy: 0.9792 - val_loss: 1.3056 - val_accuracy: 0.4375
# Epoch 77/100
# 8/8 [==============================] - 1s 103ms/step - loss: 0.4927 - accuracy: 0.9792 - val_loss: 1.3078 - val_accuracy: 0.4375
# Epoch 78/100
# 8/8 [==============================] - 1s 106ms/step - loss: 0.4884 - accuracy: 0.9792 - val_loss: 1.3104 - val_accuracy: 0.4375
# Epoch 79/100
# 8/8 [==============================] - 1s 114ms/step - loss: 0.4843 - accuracy: 0.9792 - val_loss: 1.3128 - val_accuracy: 0.4375
# Epoch 80/100
# 8/8 [==============================] - 1s 114ms/step - loss: 0.4801 - accuracy: 0.9792 - val_loss: 1.3154 - val_accuracy: 0.4375
# Epoch 81/100
# 8/8 [==============================] - 1s 116ms/step - loss: 0.4761 - accuracy: 0.9792 - val_loss: 1.3180 - val_accuracy: 0.4375
# Epoch 82/100
# 8/8 [==============================] - 1s 122ms/step - loss: 0.4721 - accuracy: 0.9792 - val_loss: 1.3209 - val_accuracy: 0.4375
# Epoch 83/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.4681 - accuracy: 0.9792 - val_loss: 1.3243 - val_accuracy: 0.4500
# Epoch 84/100
# 8/8 [==============================] - 1s 107ms/step - loss: 0.4641 - accuracy: 0.9792 - val_loss: 1.3286 - val_accuracy: 0.4375
# Epoch 85/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.4603 - accuracy: 0.9792 - val_loss: 1.3340 - val_accuracy: 0.4375
# Epoch 86/100
# 8/8 [==============================] - 1s 104ms/step - loss: 0.4565 - accuracy: 0.9792 - val_loss: 1.3410 - val_accuracy: 0.4125
# Epoch 87/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.4527 - accuracy: 0.9792 - val_loss: 1.3574 - val_accuracy: 0.4250
# Epoch 88/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.4488 - accuracy: 0.9792 - val_loss: 1.3940 - val_accuracy: 0.4375
# Epoch 89/100
# 8/8 [==============================] - 1s 103ms/step - loss: 0.4476 - accuracy: 0.9792 - val_loss: 1.4590 - val_accuracy: 0.3750
# Epoch 90/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.4454 - accuracy: 0.9792 - val_loss: 1.2278 - val_accuracy: 0.4375
# Epoch 91/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.4406 - accuracy: 0.9792 - val_loss: 1.2157 - val_accuracy: 0.4500
# Epoch 92/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.4369 - accuracy: 0.9792 - val_loss: 1.2070 - val_accuracy: 0.5000
# Epoch 93/100
# 8/8 [==============================] - 1s 107ms/step - loss: 0.4334 - accuracy: 0.9792 - val_loss: 1.2284 - val_accuracy: 0.4500
# Epoch 94/100
# 8/8 [==============================] - 1s 132ms/step - loss: 0.4302 - accuracy: 0.9792 - val_loss: 1.3696 - val_accuracy: 0.3750
# Epoch 95/100
# 8/8 [==============================] - 1s 142ms/step - loss: 0.4283 - accuracy: 0.9792 - val_loss: 1.4438 - val_accuracy: 0.4375
# Epoch 96/100
# 8/8 [==============================] - 1s 120ms/step - loss: 0.4270 - accuracy: 0.9792 - val_loss: 1.3060 - val_accuracy: 0.3625
# Epoch 97/100
# 8/8 [==============================] - 1s 121ms/step - loss: 0.4140 - accuracy: 0.9833 - val_loss: 1.3348 - val_accuracy: 0.3875
# Epoch 98/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.4096 - accuracy: 0.9833 - val_loss: 1.2360 - val_accuracy: 0.4750
# Epoch 99/100
# 8/8 [==============================] - 1s 124ms/step - loss: 0.4061 - accuracy: 0.9833 - val_loss: 1.2488 - val_accuracy: 0.4750
# Epoch 100/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.4028 - accuracy: 0.9833 - val_loss: 1.2754 - val_accuracy: 0.4500
# Time taken for Training and Classification: 89.21577739715576s

# %%
loss, accuracy = model.evaluate(X_train, train_y, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, test_y, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 0.9833
# Testing Accuracy:  0.4500

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
